# %% [markdown]
# <a href="https://colab.research.google.com/github/amiqdam/learning-journey/blob/main/Multimodal_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import os

OPENAI_API_KEYS = userdata.get("OPENAI_API_KEYS")
os.environ["OPENAI_API_KEYS"] = OPENAI_API_KEYS

# %%
# !pip install -q torch torchvision torchaudio easyocr
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 78.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 55.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.6/300.6 kB 21.7 MB/s eta 0:00:00

# %%
import easyocr
reader = easyocr.Reader(["id"])
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
# Download sample images for testing
# !wget https://blog.rosihanari.net/wp-content/uploads/2022/05/WhatsApp-Image-2022-05-22-at-7.30.08-PM.jpeg
# !wget https://nonabelanja.com/wp-content/uploads/2024/11/struk-belanja.webp
# !wget https://exceljet.net/sites/default/files/styles/original_with_watermark/public/images/chart/quarterly%20sales%20by%20clustered%20region.png
# !wget https://www.ibm.com/docs/no/SSEP7J_11.1.0/com.ibm.swg.ba.cognos.ig_smples.doc/cust_churn_info_zip_code.jpg
# Out:
# --2026-01-13 07:26:33--  https://blog.rosihanari.net/wp-content/uploads/2022/05/WhatsApp-Image-2022-05-22-at-7.30.08-PM.jpeg
# Resolving blog.rosihanari.net (blog.rosihanari.net)... 36.50.77.52, 2001:df7:5300:9::34
# Connecting to blog.rosihanari.net (blog.rosihanari.net)|36.50.77.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 150441 (147K) [image/jpeg]
# Saving to: ‘WhatsApp-Image-2022-05-22-at-7.30.08-PM.jpeg.1’
#
# WhatsApp-Image-2022 100%[===================>] 146.92K   218KB/s    in 0.7s
#
# 2026-01-13 07:26:34 (218 KB/s) - ‘WhatsApp-Image-2022-05-22-at-7.30.08-PM.jpeg.1’ saved [150441/150441]
#
# --2026-01-13 07:26:35--  https://nonabelanja.com/wp-content/uploads/2024/11/struk-belanja.webp
# Resolving nonabelanja.com (nonabelanja.com)... 45.146.6.31
# Connecting to nonabelanja.com (nonabelanja.com)|45.146.6.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18098 (18K) [image/webp]
# ...

# %%
# function processing ocr

def processing_ocr(image_path):
  # read receipt using easyOCR
  result = reader.readtext(image_path)

  # display full result wiht coordinate and confidence
  print("Full OCR Results")
  print(result)

  #extract and display the text
  print("\n Extracted Texts: ")
  for res in result:
    text = res[1] # res: [coordinate, text, confidence]
    print(f"Text: {text}")
  return result

# %%
receipt_result = processing_ocr("/content/WhatsApp-Image-2022-05-22-at-7.30.08-PM.jpeg")
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Full OCR Results
# ...

# %% [markdown]
# Multimodal

# %%
# !pip install openai

# %%
import base64
from openai import OpenAI

client = OpenAI(api_key=OPENAI_API_KEYS)

# %%
# function multimodal first option
def openai_ocr(image_path, prompt):
  with open(image_path, "rb") as f:
    image_base64 = base64.b64encode(f.read()).decode("utf-8")

  response = client.chat.completions.create(
      model="gpt-4o-mini",
      messages=[
          {
              "role": "user",
              "content": [
                  {"type": "text", "text": prompt},
                  {
                      "type": "image_url",
                      "image_url": {
                          "url": f"data:image/jpeg;base64,{image_base64}"
                      },
                  },
              ],
          }
      ],
  )

  result = response.choices[0].message.content
  print("AI OCR Results: ")
  print(result)

  return result

# %%
# function multimodal second option
def openai_ocr(image_path, prompt):
  with open(image_path, "rb") as f:
    image_base64 = base64.b64encode(f.read()).decode("utf-8")

  response = client.responses.create(
      model="gpt-4.1",
      input=[
            {
                "role": "user",
                "content": [
                    { "type": "input_text", "text": prompt },
                    {
                        "type": "input_image",
                        "image_url": f"data:image/jpeg;base64,{image_base64}",
                    },
                ],
            }
        ],
    )
  result = response.output_text
  print("AI OCR Result")
  print(result)
  return result

# %%
# # function multimodal
# def opeai_ocr(image_path, prompt):
#   with open(image_path, "rb") as f:
#     image_base64 = base64.b64encode(f.read()).decode("utf-8")

#   response = client.responses.create(
#       model = "gpt-4o-mini",
#       input=[
#           {
#               "role": "user",
#               "content" : [
#                   {"type": "input_text", "text": prompt},
#                   {
#                       "type": "input_image",
#                       "image_base64": image_base64,
#                   }
#               ]
#           }
#       ]
#   )

#   result = response.output_text
#   print("AI OCR Results: ")
#   print(result)

#   return result

# %%
cust_churn = openai_ocr("/content/cust_churn_info_zip_code.jpg", "What is the main reason of churn in our data?")
# Out:
# AI OCR Result
# The main reason for churn in your data is **"Competitor made better offer"**.
#
# This reason appears most frequently in the "Churn Reason" column of the table, indicating that most customers are leaving due to more attractive offers from competitors. The only other listed reason is "Poor expertise of online support," which appears just once, whereas "Competitor made better offer" appears repeatedly for nearly every other customer.

# %%
from IPython.display import Markdown

Markdown(cust_churn)
# Out:
# The main reason for churn in your data is **"Competitor made better offer"**.
#
# This reason appears most frequently in the "Churn Reason" column of the table, indicating that most customers are leaving due to more attractive offers from competitors. The only other listed reason is "Poor expertise of online support," which appears just once, whereas "Competitor made better offer" appears repeatedly for nearly every other customer.
